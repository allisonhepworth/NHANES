# %%
import pandas as pd
import numpy as np
import seaborn as sns
import duckdb as db
import matplotlib.pyplot as plt
import scipy.stats as stats

# %%
df_dietary_1 = pd.read_sas('/Users/soumyadeepray/Library/Mobile Documents/com~apple~CloudDocs/Documents/Research_Project-Nutrition_Sciences/NHANES/data/P_DR1IFF.XPT')
df_dietary_2 = pd.read_sas('/Users/soumyadeepray/Library/Mobile Documents/com~apple~CloudDocs/Documents/Research_Project-Nutrition_Sciences/NHANES/data/P_DR2IFF.XPT')

# %%
df_total_nutrient_1 = pd.read_sas('/Users/soumyadeepray/Library/Mobile Documents/com~apple~CloudDocs/Documents/Research_Project-Nutrition_Sciences/NHANES/data/P_DR1TOT.XPT')
df_total_nutrient_2 = pd.read_sas('/Users/soumyadeepray/Library/Mobile Documents/com~apple~CloudDocs/Documents/Research_Project-Nutrition_Sciences/NHANES/data/P_DR2TOT.XPT')
# Out:
# /var/folders/jk/45pfmj415lb9l0__2lq4xmr40000gn/T/ipykernel_20430/2422103708.py:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_total_nutrient_1 = pd.read_sas('/Users/soumyadeepray/Library/Mobile Documents/com~apple~CloudDocs/Documents/Research_Project-Nutrition_Sciences/NHANES/data/P_DR1TOT.XPT')
# /var/folders/jk/45pfmj415lb9l0__2lq4xmr40000gn/T/ipykernel_20430/2422103708.py:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# ...

# %%
df_demo = pd.read_sas('/Users/soumyadeepray/Library/Mobile Documents/com~apple~CloudDocs/Documents/Research_Project-Nutrition_Sciences/NHANES/data/P_DEMO.XPT')

# %%
df_BMX = pd.read_sas('/Users/soumyadeepray/Library/Mobile Documents/com~apple~CloudDocs/Documents/Research_Project-Nutrition_Sciences/NHANES/data/P_BMX.XPT')

# %%
df_dietary_1
# Out:
#             SEQN     WTDRD1PP      WTDR2DPP  DR1ILINE  DR1DRSTZ  DR1EXMER  \
# 0       109263.0  7619.483586  1.780807e+04      12.0       1.0      14.0
# 1       109263.0  7619.483586  1.780807e+04      10.0       1.0      14.0
# 2       109263.0  7619.483586  1.780807e+04       4.0       1.0      14.0
# 3       109263.0  7619.483586  1.780807e+04       9.0       1.0      14.0
# 4       109263.0  7619.483586  1.780807e+04      13.0       1.0      14.0
# ...          ...          ...           ...       ...       ...       ...
# 183905  124821.0  3043.724330  5.397605e-79       5.0       1.0      81.0
# 183906  124821.0  3043.724330  5.397605e-79       4.0       1.0      81.0
# 183907  124821.0  3043.724330  5.397605e-79       3.0       1.0      81.0
# 183908  124821.0  3043.724330  5.397605e-79       2.0       1.0      81.0
# 183909  124821.0  3043.724330  5.397605e-79       1.0       1.0      81.0
#
#         DRABF  DRDINT       DR1DBIH  DR1DAY  ...      DR1IM181      DR1IM201  \
# ...

# %%
q_1 = db.sql('select SEQN, DR1DAY, sum(DR1IKCAL) TOT1KCAL , sum(DR1IPROT) TOT1PROT, sum(DR1ICARB) TOT1CARB, sum(DR1ISUGR) TOT1SUGR, sum(DR1IFIBE) TOT1FIBE, sum(DR1ITFAT) TOT1FAT, sum(DR1IATOC) TOT1ATOC, sum(DR1ISODI) TOT1SODI from df_dietary_1 group by SEQN, DR1DAY').df()
q_1
# Out:
#            SEQN  DR1DAY  TOT1KCAL  TOT1PROT  TOT1CARB  TOT1SUGR  TOT1FIBE  \
# 0      118027.0     6.0     771.0     41.45     89.37     28.08       8.4
# 1      118039.0     5.0     849.0     21.17     80.91     30.36       9.6
# 2      118040.0     3.0    3605.0    119.29    470.53    225.58      15.5
# 3      118044.0     1.0    1864.0     68.89    128.94     40.15      13.4
# 4      118046.0     6.0    1536.0     46.06    162.79     62.28      13.0
# ...         ...     ...       ...       ...       ...       ...       ...
# 12627  109454.0     6.0     478.0     12.76     69.01     37.02       2.9
# 12628  110214.0     7.0    3935.0    149.58    390.50    131.38      14.9
# 12629  114946.0     6.0     760.0     18.07    131.07     81.21       7.9
# 12630  115964.0     6.0    1264.0     35.36    163.69     81.67       9.4
# 12631  117635.0     5.0    1027.0     30.75    148.87    142.92       0.1
#
#        TOT1FAT  TOT1ATOC  TOT1SODI
# 0        29.39      2.12    1411.0
# ...

# %%
q_2 = db.sql('select SEQN, DR2DAY, sum(DR2IKCAL) TOT2KCAL , sum(DR2IPROT) TOT2PROT, sum(DR2ICARB) TOT2CARB, sum(DR2ISUGR) TOT2SUGR, sum(DR2IFIBE) TOT2FIBE, sum(DR2ITFAT) TOT2FAT, sum(DR2IATOC) TOT2ATOC, sum(DR2ISODI) TOT2SODI from df_dietary_2 group by SEQN, DR2DAY').df()
q_2
# Out:
#            SEQN  DR2DAY  TOT2KCAL  TOT2PROT  TOT2CARB  TOT2SUGR      TOT2FIBE  \
# 0      120015.0     5.0    1630.0     43.99    202.10    148.03  4.000000e+00
# 1      120016.0     1.0    5356.0    163.59    669.16    279.90  2.700000e+01
# 2      120018.0     5.0     795.0     28.74    127.62     73.32  3.238563e-78
# 3      120023.0     7.0    1508.0     60.72    196.71    137.23  1.450000e+01
# 4      120031.0     3.0    1772.0     75.87    263.14    101.87  1.870000e+01
# ...         ...     ...       ...       ...       ...       ...           ...
# 10825  116480.0     5.0    3038.0     88.16    298.17    111.48  2.920000e+01
# 10826  117970.0     5.0    1334.0     54.76    183.72    100.86  1.020000e+01
# 10827  117989.0     4.0    3227.0    118.51    436.37    208.98  3.200000e+01
# 10828  111813.0     4.0    1556.0     59.67    222.01     65.47  1.850000e+01
# 10829  114275.0     2.0     563.0     32.27     74.53     15.22  9.000000e+00
#
# ...

# %%
merged_df = pd.merge(q_1, q_2, on='SEQN', how='outer')
#merged_df = pd.merge(q_1, df_demo, on='SEQN', how='left')
merged_df
# Out:
#            SEQN  DR1DAY  TOT1KCAL  TOT1PROT  TOT1CARB  TOT1SUGR  TOT1FIBE  \
# 0      118027.0     6.0     771.0     41.45     89.37     28.08       8.4
# 1      118039.0     5.0     849.0     21.17     80.91     30.36       9.6
# 2      118040.0     3.0    3605.0    119.29    470.53    225.58      15.5
# 3      118044.0     1.0    1864.0     68.89    128.94     40.15      13.4
# 4      118046.0     6.0    1536.0     46.06    162.79     62.28      13.0
# ...         ...     ...       ...       ...       ...       ...       ...
# 12629  114946.0     6.0     760.0     18.07    131.07     81.21       7.9
# 12630  115964.0     6.0    1264.0     35.36    163.69     81.67       9.4
# 12631  117635.0     5.0    1027.0     30.75    148.87    142.92       0.1
# 12632  117012.0     NaN       NaN       NaN       NaN       NaN       NaN
# 12633  110939.0     NaN       NaN       NaN       NaN       NaN       NaN
#
#        TOT1FAT  TOT1ATOC  TOT1SODI  DR2DAY  TOT2KCAL  TOT2PROT  TOT2CARB  \
# ...

# %%
merged_df.T
# Out:
#               0          1          2          3          4          5      \
# SEQN      118027.00  118039.00  118040.00  118044.00  118046.00  118064.00
# DR1DAY         6.00       5.00       3.00       1.00       6.00       6.00
# TOT1KCAL     771.00     849.00    3605.00    1864.00    1536.00    2144.00
# TOT1PROT      41.45      21.17     119.29      68.89      46.06      92.70
# TOT1CARB      89.37      80.91     470.53     128.94     162.79     230.25
# TOT1SUGR      28.08      30.36     225.58      40.15      62.28      60.93
# TOT1FIBE       8.40       9.60      15.50      13.40      13.00      11.80
# TOT1FAT       29.39      23.75     141.74     119.34      78.80      94.48
# TOT1ATOC       2.12      10.46      12.15      10.03       5.20       5.21
# TOT1SODI    1411.00     817.00    5932.00    4153.00    2521.00    5282.00
# DR2DAY         3.00       6.00       1.00       5.00        NaN       2.00
# ...

# %% [markdown]
# ### MANUAL SELECTION of respondents

# %%
merged_df.loc[merged_df['SEQN'] == 118030.0]
# Out:
#        SEQN  TOT1KCAL  TOT1PROT  TOT1CARB  TOT1SUGR  TOT1FIBE  TOT1FAT  \
# 0  118030.0    1179.0     33.77    129.31     76.44       8.7    60.66
#
#    TOT1ATOC  TOT1SODI  TOT2KCAL  TOT2PROT  TOT2CARB  TOT2SUGR  TOT2FIBE  \
# 0      5.51    1247.0     835.0     27.71     78.13     39.84       2.5
#
#    TOT2FAT  TOT2ATOC  TOT2SODI
# 0    40.51      2.54    1588.0

# %%
merged_df.loc[merged_df['SEQN'] == 118030.0].T
# Out:
#                   0
# SEQN      118030.00
# TOT1KCAL    1179.00
# TOT1PROT      33.77
# TOT1CARB     129.31
# TOT1SUGR      76.44
# TOT1FIBE       8.70
# TOT1FAT       60.66
# TOT1ATOC       5.51
# TOT1SODI    1247.00
# TOT2KCAL     835.00
# TOT2PROT      27.71
# TOT2CARB      78.13
# TOT2SUGR      39.84
# TOT2FIBE       2.50
# TOT2FAT       40.51
# TOT2ATOC       2.54
# TOT2SODI    1588.00

# %% [markdown]
# ### RANDOM SELECTION of respondents

# %%
import random

# %%
merged_df['SEQN'].describe()
# Out:
# count     12634.000000
# mean     117103.994697
# std        4499.703167
# min      109263.000000
# 25%      113222.250000
# 50%      117147.500000
# 75%      121007.750000
# max      124821.000000
# Name: SEQN, dtype: float64

# %% [markdown]
# There are a total of 12634 unique SEQN in the whole dataset. So, we will randomly select a number between 109263 and 124821.

# %%
random.seed()
sample_id = random.sample(list(range(109263 ,124822)), 1)
sample_id
# Out:
# [120318]

# %%
merged_df.loc[merged_df['SEQN'] == 110718]
# Out:
#           SEQN  TOT1KCAL  TOT1PROT  TOT1CARB  TOT1SUGR  TOT1FIBE  TOT1FAT  \
# 3961  110718.0    1651.0     48.68    157.01     18.21      11.3     91.9
#
#       TOT1ATOC  TOT1SODI  TOT2KCAL  TOT2PROT  TOT2CARB  TOT2SUGR  TOT2FIBE  \
# 3961       8.6    3153.0       NaN       NaN       NaN       NaN       NaN
#
#       TOT2FAT  TOT2ATOC  TOT2SODI
# 3961      NaN       NaN       NaN

# %%
merged_df.loc[merged_df['SEQN'] == 110718].T
# Out:
#                3961
# SEQN      110718.00
# TOT1KCAL    1651.00
# TOT1PROT      48.68
# TOT1CARB     157.01
# TOT1SUGR      18.21
# TOT1FIBE      11.30
# TOT1FAT       91.90
# TOT1ATOC       8.60
# TOT1SODI    3153.00
# TOT2KCAL        NaN
# TOT2PROT        NaN
# TOT2CARB        NaN
# TOT2SUGR        NaN
# TOT2FIBE        NaN
# TOT2FAT         NaN
# TOT2ATOC        NaN
# TOT2SODI        NaN

# %%
merged_df = pd.merge( merged_df, df_demo, on='SEQN', how='left')
merged_df
# Out:
#            SEQN  DR1DAY  TOT1KCAL  TOT1PROT  TOT1CARB  TOT1SUGR  TOT1FIBE  \
# 0      118027.0     6.0     771.0     41.45     89.37     28.08       8.4
# 1      118039.0     5.0     849.0     21.17     80.91     30.36       9.6
# 2      118040.0     3.0    3605.0    119.29    470.53    225.58      15.5
# 3      118044.0     1.0    1864.0     68.89    128.94     40.15      13.4
# 4      118046.0     6.0    1536.0     46.06    162.79     62.28      13.0
# ...         ...     ...       ...       ...       ...       ...       ...
# 12629  114946.0     6.0     760.0     18.07    131.07     81.21       7.9
# 12630  115964.0     6.0    1264.0     35.36    163.69     81.67       9.4
# 12631  117635.0     5.0    1027.0     30.75    148.87    142.92       0.1
# 12632  117012.0     NaN       NaN       NaN       NaN       NaN       NaN
# 12633  110939.0     NaN       NaN       NaN       NaN       NaN       NaN
#
#        TOT1FAT  TOT1ATOC  TOT1SODI  ...  FIAINTRP  MIALANG  MIAPROXY  \
# ...

# %%
merged_df_1 = pd.merge(merged_df, df_BMX, how='left', on='SEQN')

# %%
merged_df_1
# Out:
#            SEQN  DR1DAY  TOT1KCAL  TOT1PROT  TOT1CARB  TOT1SUGR  TOT1FIBE  \
# 0      118027.0     6.0     771.0     41.45     89.37     28.08       8.4
# 1      118039.0     5.0     849.0     21.17     80.91     30.36       9.6
# 2      118040.0     3.0    3605.0    119.29    470.53    225.58      15.5
# 3      118044.0     1.0    1864.0     68.89    128.94     40.15      13.4
# 4      118046.0     6.0    1536.0     46.06    162.79     62.28      13.0
# ...         ...     ...       ...       ...       ...       ...       ...
# 12629  114946.0     6.0     760.0     18.07    131.07     81.21       7.9
# 12630  115964.0     6.0    1264.0     35.36    163.69     81.67       9.4
# 12631  117635.0     5.0    1027.0     30.75    148.87    142.92       0.1
# 12632  117012.0     NaN       NaN       NaN       NaN       NaN       NaN
# 12633  110939.0     NaN       NaN       NaN       NaN       NaN       NaN
#
#        TOT1FAT  TOT1ATOC  TOT1SODI  ...  BMXLEG  BMILEG  BMXARML  BMIARML  \
# ...

# %%
merged_df_1.columns
# Out:
# Index(['SEQN', 'DR1DAY', 'TOT1KCAL', 'TOT1PROT', 'TOT1CARB', 'TOT1SUGR',
#        'TOT1FIBE', 'TOT1FAT', 'TOT1ATOC', 'TOT1SODI', 'DR2DAY', 'TOT2KCAL',
#        'TOT2PROT', 'TOT2CARB', 'TOT2SUGR', 'TOT2FIBE', 'TOT2FAT', 'TOT2ATOC',
#        'TOT2SODI', 'SDDSRVYR', 'RIDSTATR', 'RIAGENDR', 'RIDAGEYR', 'RIDAGEMN',
#        'RIDRETH1', 'RIDRETH3', 'RIDEXMON', 'DMDBORN4', 'DMDYRUSZ', 'DMDEDUC2',
#        'DMDMARTZ', 'RIDEXPRG', 'SIALANG', 'SIAPROXY', 'SIAINTRP', 'FIALANG',
#        'FIAPROXY', 'FIAINTRP', 'MIALANG', 'MIAPROXY', 'MIAINTRP', 'AIALANGA',
#        'WTINTPRP', 'WTMECPRP', 'SDMVPSU', 'SDMVSTRA', 'INDFMPIR', 'BMDSTATS',
#        'BMXWT', 'BMIWT', 'BMXRECUM', 'BMIRECUM', 'BMXHEAD', 'BMIHEAD', 'BMXHT',
#        'BMIHT', 'BMXBMI', 'BMDBMIC', 'BMXLEG', 'BMILEG', 'BMXARML', 'BMIARML',
#        'BMXARMC', 'BMIARMC', 'BMXWAIST', 'BMIWAIST', 'BMXHIP', 'BMIHIP'],
#       dtype='object')

# %%
df = merged_df_1[['SEQN', 'DR1DAY', 'TOT1KCAL', 'TOT1PROT', 'TOT1CARB', 'TOT1SUGR', 'TOT1FIBE',
       'TOT1FAT', 'TOT1ATOC', 'TOT1SODI', 'DR2DAY', 'TOT2KCAL', 'TOT2PROT', 'TOT2CARB',
       'TOT2SUGR', 'TOT2FIBE', 'TOT2FAT', 'TOT2ATOC', 'TOT2SODI',
       'SIAPROXY', 'RIDAGEYR', 'RIDAGEMN', 'RIAGENDR', 'RIDRETH1', 'RIDRETH3', 'DMDMARTZ', 'DMDEDUC2', 'INDFMPIR', 'RIDEXPRG', 'DMDYRUSZ', 'SIALANG',
       'BMXBMI', 'BMDBMIC', 'BMXWT', 'BMXHT', 'BMXRECUM', 'BMXWAIST', 'BMXHIP']]

# %%
df[['SEQN', 'SIAPROXY', 'RIDAGEYR', 'RIDAGEMN', 'RIAGENDR', 'RIDRETH1', 'RIDRETH3', 'DMDMARTZ', 'DMDEDUC2', 'INDFMPIR', 'RIDEXPRG', 'DMDYRUSZ', 'SIALANG',
       'BMXBMI', 'BMDBMIC', 'BMXWT', 'BMXHT', 'BMXRECUM', 'BMXWAIST', 'BMXHIP']].loc[df['SEQN'] == 120318].T
# Out:
#               3348
# SEQN      120318.0
# DR1DAY         7.0
# SIAPROXY       1.0
# RIDAGEYR      13.0
# RIDAGEMN       NaN
# RIAGENDR       2.0
# RIDRETH1       1.0
# RIDRETH3       1.0
# DMDMARTZ       NaN
# DMDEDUC2       NaN
# INDFMPIR       NaN
# RIDEXPRG       NaN
# DMDYRUSZ       NaN
# SIALANG        2.0
# BMXBMI        27.1
# BMDBMIC        4.0
# BMXWT         74.7
# BMXHT        165.9
# BMXRECUM       NaN
# BMXWAIST      95.3
# BMXHIP       101.9

# %%
df[['SEQN', 'DR1DAY','TOT1KCAL', 'TOT1PROT', 'TOT1CARB', 'TOT1SUGR', 'TOT1FIBE','TOT1FAT', 'TOT1ATOC', 'TOT1SODI', 'DR2DAY', 'TOT2KCAL', 'TOT2PROT', 
    'TOT2CARB','TOT2SUGR', 'TOT2FIBE', 'TOT2FAT', 'TOT2ATOC', 'TOT2SODI']].loc[df['SEQN'] == 120318].T
# Out:
#                3348
# SEQN      120318.00
# DR1DAY         7.00
# TOT1KCAL    1023.00
# TOT1PROT      24.77
# TOT1CARB     162.78
# TOT1SUGR      81.42
# TOT1FIBE       9.40
# TOT1FAT       30.43
# TOT1ATOC       4.07
# TOT1SODI    1557.00
# DR2DAY         3.00
# TOT2KCAL     716.00
# TOT2PROT      34.60
# TOT2CARB     100.08
# TOT2SUGR      18.38
# TOT2FIBE       5.20
# TOT2FAT       20.18
# TOT2ATOC       3.97
# TOT2SODI    1214.00

# %%
df_dietary_1.columns
# Out:
# Index(['SEQN', 'WTDRD1PP', 'WTDR2DPP', 'DR1ILINE', 'DR1DRSTZ', 'DR1EXMER',
#        'DRABF', 'DRDINT', 'DR1DBIH', 'DR1DAY', 'DR1LANG', 'DR1CCMNM',
#        'DR1CCMTX', 'DR1_020', 'DR1_030Z', 'DR1FS', 'DR1_040Z', 'DR1IFDCD',
#        'DR1IGRMS', 'DR1IKCAL', 'DR1IPROT', 'DR1ICARB', 'DR1ISUGR', 'DR1IFIBE',
#        'DR1ITFAT', 'DR1ISFAT', 'DR1IMFAT', 'DR1IPFAT', 'DR1ICHOL', 'DR1IATOC',
#        'DR1IATOA', 'DR1IRET', 'DR1IVARA', 'DR1IACAR', 'DR1IBCAR', 'DR1ICRYP',
#        'DR1ILYCO', 'DR1ILZ', 'DR1IVB1', 'DR1IVB2', 'DR1INIAC', 'DR1IVB6',
#        'DR1IFOLA', 'DR1IFA', 'DR1IFF', 'DR1IFDFE', 'DR1ICHL', 'DR1IVB12',
#        'DR1IB12A', 'DR1IVC', 'DR1IVD', 'DR1IVK', 'DR1ICALC', 'DR1IPHOS',
#        'DR1IMAGN', 'DR1IIRON', 'DR1IZINC', 'DR1ICOPP', 'DR1ISODI', 'DR1IPOTA',
#        'DR1ISELE', 'DR1ICAFF', 'DR1ITHEO', 'DR1IALCO', 'DR1IMOIS', 'DR1IS040',
#        'DR1IS060', 'DR1IS080', 'DR1IS100', 'DR1IS120', 'DR1IS140', 'DR1IS160',
# ...

# %%
df_1 = df_dietary_1[['SEQN', 'DR1ILINE', 'DR1DRSTZ',
       'DRABF', 'DRDINT', 'DR1DAY', 'DR1LANG', 'DR1CCMNM',
       'DR1CCMTX', 'DR1_020', 'DR1_030Z', 'DR1FS', 'DR1_040Z', 'DR1IFDCD',
       'DR1IGRMS', 'DR1IKCAL', 'DR1IPROT', 'DR1ICARB', 'DR1ISUGR', 'DR1IFIBE',
       'DR1ITFAT', 'DR1ISFAT', 'DR1IMFAT', 'DR1IPFAT', 'DR1ICHOL', 'DR1IATOC',
       'DR1IATOA', 'DR1IRET', 'DR1IVARA', 'DR1IACAR', 'DR1IBCAR', 'DR1ICRYP',
       'DR1ILYCO', 'DR1ILZ', 'DR1IVB1', 'DR1IVB2', 'DR1INIAC', 'DR1IVB6',
       'DR1IFOLA', 'DR1IFA', 'DR1IFF', 'DR1IFDFE', 'DR1ICHL', 'DR1IVB12',
       'DR1IB12A', 'DR1IVC', 'DR1IVD', 'DR1IVK', 'DR1ICALC', 'DR1IPHOS',
       'DR1IMAGN', 'DR1IIRON', 'DR1IZINC', 'DR1ICOPP', 'DR1ISODI', 'DR1IPOTA',
       'DR1ISELE', 'DR1ICAFF', 'DR1ITHEO', 'DR1IALCO', 'DR1IMOIS']].loc[df_dietary_1['SEQN']==120318]

# %%
df_1.to_csv('/Users/soumyadeepray/Library/Mobile Documents/com~apple~CloudDocs/Documents/Research_Project-Nutrition_Sciences/NHANES/data/Dietary_data_1_120318.csv')

# %%
df_dietary_2.columns
# Out:
# Index(['SEQN', 'WTDRD1PP', 'WTDR2DPP', 'DR2ILINE', 'DR2DRSTZ', 'DR2EXMER',
#        'DRABF', 'DRDINT', 'DR2DBIH', 'DR2DAY', 'DR2LANG', 'DR2CCMNM',
#        'DR2CCMTX', 'DR2_020', 'DR2_030Z', 'DR2FS', 'DR2_040Z', 'DR2IFDCD',
#        'DR2IGRMS', 'DR2IKCAL', 'DR2IPROT', 'DR2ICARB', 'DR2ISUGR', 'DR2IFIBE',
#        'DR2ITFAT', 'DR2ISFAT', 'DR2IMFAT', 'DR2IPFAT', 'DR2ICHOL', 'DR2IATOC',
#        'DR2IATOA', 'DR2IRET', 'DR2IVARA', 'DR2IACAR', 'DR2IBCAR', 'DR2ICRYP',
#        'DR2ILYCO', 'DR2ILZ', 'DR2IVB1', 'DR2IVB2', 'DR2INIAC', 'DR2IVB6',
#        'DR2IFOLA', 'DR2IFA', 'DR2IFF', 'DR2IFDFE', 'DR2ICHL', 'DR2IVB12',
#        'DR2IB12A', 'DR2IVC', 'DR2IVD', 'DR2IVK', 'DR2ICALC', 'DR2IPHOS',
#        'DR2IMAGN', 'DR2IIRON', 'DR2IZINC', 'DR2ICOPP', 'DR2ISODI', 'DR2IPOTA',
#        'DR2ISELE', 'DR2ICAFF', 'DR2ITHEO', 'DR2IALCO', 'DR2IMOIS', 'DR2IS040',
#        'DR2IS060', 'DR2IS080', 'DR2IS100', 'DR2IS120', 'DR2IS140', 'DR2IS160',
# ...

# %%
df_2 = df_dietary_2[['SEQN',  'DR2ILINE', 'DR2DRSTZ', 
       'DRABF', 'DRDINT', 'DR2DAY', 'DR2LANG', 'DR2CCMNM',
       'DR2CCMTX', 'DR2_020', 'DR2_030Z', 'DR2FS', 'DR2_040Z', 'DR2IFDCD',
       'DR2IGRMS', 'DR2IKCAL', 'DR2IPROT', 'DR2ICARB', 'DR2ISUGR', 'DR2IFIBE',
       'DR2ITFAT', 'DR2ISFAT', 'DR2IMFAT', 'DR2IPFAT', 'DR2ICHOL', 'DR2IATOC',
       'DR2IATOA', 'DR2IRET', 'DR2IVARA', 'DR2IACAR', 'DR2IBCAR', 'DR2ICRYP',
       'DR2ILYCO', 'DR2ILZ', 'DR2IVB1', 'DR2IVB2', 'DR2INIAC', 'DR2IVB6',
       'DR2IFOLA', 'DR2IFA', 'DR2IFF', 'DR2IFDFE', 'DR2ICHL', 'DR2IVB12',
       'DR2IB12A', 'DR2IVC', 'DR2IVD', 'DR2IVK', 'DR2ICALC', 'DR2IPHOS',
       'DR2IMAGN', 'DR2IIRON', 'DR2IZINC', 'DR2ICOPP', 'DR2ISODI', 'DR2IPOTA',
       'DR2ISELE', 'DR2ICAFF', 'DR2ITHEO', 'DR2IALCO', 'DR2IMOIS']].loc[df_dietary_2['SEQN']==120318]

# %%
df_2.to_csv('/Users/soumyadeepray/Library/Mobile Documents/com~apple~CloudDocs/Documents/Research_Project-Nutrition_Sciences/NHANES/data/Dietary_data_2_120318.csv')

# %%
df_total_nutrient_1['SEQN'].value_counts()
# Out:
# 109263.0    1
# 119688.0    1
# 119676.0    1
# 119677.0    1
# 119678.0    1
#            ..
# 114468.0    1
# 114469.0    1
# 114470.0    1
# 114471.0    1
# 124822.0    1
# Name: SEQN, Length: 14300, dtype: int64

# %%
q_3 = db.sql('select count (distinct SEQN) from df_total_nutrient_1')
q_3
# Out:
# ┌────────────────────────┐
# │ count(DISTINCT "SEQN") │
# │         int64          │
# ├────────────────────────┤
# │                  14300 │
# └────────────────────────┘

# %%
q_4 = db.sql('select count (distinct SEQN) from df_total_nutrient_2')
q_4
# Out:
# ┌────────────────────────┐
# │ count(DISTINCT "SEQN") │
# │         int64          │
# ├────────────────────────┤
# │                  14300 │
# └────────────────────────┘

# %%
merged_total_nutrient_df = pd.merge(df_total_nutrient_1, df_total_nutrient_2, on='SEQN', how='outer')
merged_total_nutrient_df
# Out:
#            SEQN    WTDRD1PP_x    WTDR2DPP_x  DR1DRSTZ  DR1EXMER  DRABF_x  \
# 0      109263.0  7.619484e+03  1.780807e+04       1.0      14.0      2.0
# 1      109264.0  8.235896e+03  7.253762e+03       1.0      81.0      2.0
# 2      109265.0  3.353508e+04  3.561201e+04       1.0      88.0      2.0
# 3      109266.0  6.831068e+03  5.988204e+03       1.0      81.0      2.0
# 4      109269.0  7.875707e+03  1.823193e+04       1.0      88.0      2.0
# ...         ...           ...           ...       ...       ...      ...
# 14295  124818.0  1.546208e+04  1.243740e+04       1.0      49.0      2.0
# 14296  124819.0  4.091615e+03  4.100758e+03       1.0      14.0      2.0
# 14297  124820.0  3.435783e+04  3.505186e+04       1.0      86.0      2.0
# 14298  124821.0  3.043724e+03  5.397605e-79       1.0      81.0      2.0
# 14299  124822.0  5.397605e-79           NaN       2.0      14.0      NaN
#
#        DRDINT_x       DR1DBIH  DR1DAY  DR1LANG  ...      DR2TP184  DR2TP204  \
# ...

# %%
q_5 = db.sql('select SEQN, DR1DAY, sum(DR1IKCAL) TOT1KCAL , sum(DR1IPROT) TOT1PROT, sum(DR1ICARB) TOT1CARB, sum(DR1ISUGR) TOT1SUGR, sum(DR1IFIBE) TOT1FIBE, sum(DR1ITFAT) TOT1FAT, sum(DR1IATOC) TOT1ATOC, sum(DR1ISODI) TOT1SODI from df_dietary_1 group by SEQN, DR1DAY').df()
q_5

# %%
merged_total_nutrient_df.loc[merged_total_nutrient_df['SEQN']==124822.0].T
# Out:
#                    14299
# SEQN        1.248220e+05
# WTDRD1PP_x  5.397605e-79
# WTDR2DPP_x           NaN
# DR1DRSTZ    2.000000e+00
# DR1EXMER    1.400000e+01
# ...                  ...
# DR2_300              NaN
# DR2_320Z             NaN
# DR2_330Z             NaN
# DR2BWATZ             NaN
# DR2TWSZ              NaN
#
# [252 rows x 1 columns]
