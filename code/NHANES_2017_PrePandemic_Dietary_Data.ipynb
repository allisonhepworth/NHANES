# %%
import pandas as pd

# %%
Dietary_Interview_df = pd.read_sas('/Users/soumyadeepray/Documents/Research_Project-Nutrition_Sciences/NHANES/data/P_DR1IFF.XPT')

# %%
Dietary_Interview_df
# Out:
#             SEQN     WTDRD1PP      WTDR2DPP  DR1ILINE  DR1DRSTZ  DR1EXMER  \
# 0       109263.0  7619.483586  1.780807e+04      12.0       1.0      14.0
# 1       109263.0  7619.483586  1.780807e+04      10.0       1.0      14.0
# 2       109263.0  7619.483586  1.780807e+04       4.0       1.0      14.0
# 3       109263.0  7619.483586  1.780807e+04       9.0       1.0      14.0
# 4       109263.0  7619.483586  1.780807e+04      13.0       1.0      14.0
# ...          ...          ...           ...       ...       ...       ...
# 183905  124821.0  3043.724330  5.397605e-79       5.0       1.0      81.0
# 183906  124821.0  3043.724330  5.397605e-79       4.0       1.0      81.0
# 183907  124821.0  3043.724330  5.397605e-79       3.0       1.0      81.0
# 183908  124821.0  3043.724330  5.397605e-79       2.0       1.0      81.0
# 183909  124821.0  3043.724330  5.397605e-79       1.0       1.0      81.0
#
#         DRABF  DRDINT       DR1DBIH  DR1DAY  ...      DR1IM181      DR1IM201  \
# ...

# %%
Dietary_Interview_df2 = pd.read_sas('/Users/soumyadeepray/Documents/Research_Project-Nutrition_Sciences/NHANES/data/P_DR2IFF.XPT')

# %%
Dietary_Interview_df.describe()
# Out:
#                 SEQN       WTDRD1PP      WTDR2DPP       DR1ILINE  \
# count  183910.000000  183910.000000  1.839100e+05  183910.000000
# mean   117091.688141   26936.526968  2.727404e+04       9.003192
# std      4495.637420   36197.685279  4.368438e+04       6.056732
# min    109263.000000     805.552485  5.397605e-79       1.000000
# 25%    113215.000000    8030.148191  5.317873e+03       4.000000
# 50%    117143.000000   15105.403495  1.342615e+04       8.000000
# 75%    120978.000000   30874.730753  3.139270e+04      13.000000
# max    124821.000000  538404.429708  7.029436e+05      46.000000
#
#             DR1DRSTZ       DR1EXMER          DRABF         DRDINT  \
# count  183910.000000  183910.000000  183910.000000  183910.000000
# mean        1.047436      72.913876       1.984134       1.864048
# std         0.374245      21.422692       0.124959       0.342739
# min         1.000000      14.000000       1.000000       1.000000
# ...

# %%
Dietary_Interview_df.to_csv('/Users/soumyadeepray/Documents/Research_Project-Nutrition_Sciences/NHANES/data/P_DR1IFF.csv')

# %%
Dietary_Interview_df2.to_csv('/Users/soumyadeepray/Documents/Research_Project-Nutrition_Sciences/NHANES/data/P_DR2IFF.csv')

# %%
Reproductive_Health_df = pd.read_sas('/Users/soumyadeepray/Documents/Research_Project-Nutrition_Sciences/NHANES/data/P_RHQ.XPT')

# %%
Reproductive_Health_df.describe()
# Out:
#                 SEQN        RHQ010       RHD018    RHQ020       RHQ031  \
# count    5314.000000  4.932000e+03   732.000000  50.00000  4870.000000
# mean   117038.059089  2.299128e+01   781.215847   4.08000     1.480903
# std      4488.643083  1.011786e+02  2416.213595   2.50583     0.550905
# min    109264.000000  5.397605e-79   103.000000   1.00000     1.000000
# 25%    113162.250000  1.100000e+01   139.000000   2.25000     1.000000
# 50%    117056.000000  1.200000e+01   150.000000   3.00000     1.000000
# 75%    120924.750000  1.400000e+01   162.000000   4.00000     2.000000
# max    124817.000000  9.990000e+02  9999.000000   9.00000     9.000000
#
#             RHD043       RHQ060     RHQ070       RHQ074       RHQ076  ...  \
# count  2275.000000  2300.000000  94.000000  2836.000000  2836.000000  ...
# mean      6.041319    85.410870  28.829787     1.903385     1.933004  ...
# std       5.911771   192.499831  41.330724     0.398200     0.321631  ...
# ...

# %%
Reproductive_Health_df.to_csv('/Users/soumyadeepray/Documents/Research_Project-Nutrition_Sciences/NHANES/data/P_RHQ.csv')

# %%
df = pd.merge(Dietary_Interview_df, Reproductive_Health_df, how='inner', on = 'SEQN')

# %%
df.describe()
# Out:
#                 SEQN       WTDRD1PP      WTDR2DPP      DR1ILINE  DR1DRSTZ  \
# count   71949.000000   71949.000000  7.194900e+04  71949.000000   71949.0
# mean   117079.250358   30630.925515  3.125716e+04      9.291373       1.0
# std      4472.675436   39063.977341  4.751223e+04      6.293172       0.0
# min    109264.000000    1551.658449  5.397605e-79      1.000000       1.0
# 25%    113257.000000    9367.487213  6.608144e+03      4.000000       1.0
# 50%    117105.000000   17415.112298  1.603896e+04      8.000000       1.0
# 75%    120931.000000   35237.600842  3.719980e+04     13.000000       1.0
# max    124817.000000  538404.429708  7.029436e+05     46.000000       1.0
#
#            DR1EXMER    DRABF        DRDINT       DR1DBIH        DR1DAY  ...  \
# count  71949.000000  71949.0  71949.000000  68461.000000  71949.000000  ...
# mean      72.560856      2.0      1.882500     11.912622      4.532572  ...
# ...

# %%
df['RHD143'].value_counts()
# Out:
# 2.0    13982
# 1.0     1005
# 9.0      231
# Name: RHD143, dtype: int64

# %%
RHD143_df = df[df['RHD143']== 1.0]

# %%
RHD143_df.describe()
# Out:
#                 SEQN       WTDRD1PP      WTDR2DPP     DR1ILINE  DR1DRSTZ  \
# count    1005.000000    1005.000000  1.005000e+03  1005.000000    1005.0
# mean   117738.238806   29676.796425  3.152491e+04     9.539303       1.0
# std      4350.648096   26868.132806  3.829596e+04     6.283928       0.0
# min    109447.000000    1799.980997  5.397605e-79     1.000000       1.0
# 25%    113830.000000   10712.248557  5.930629e+03     4.000000       1.0
# 50%    117595.000000   20337.343422  1.720451e+04     9.000000       1.0
# 75%    121924.000000   41066.068922  4.157837e+04    13.000000       1.0
# max    124780.000000  141338.343374  1.908676e+05    31.000000       1.0
#
#           DR1EXMER   DRABF       DRDINT       DR1DBIH       DR1DAY  ...  \
# count  1005.000000  1005.0  1005.000000  9.620000e+02  1005.000000  ...
# mean     73.165174     2.0     1.848756  9.883576e+00     5.049751  ...
# std      21.093856     0.0     0.358465  1.403693e+01     2.105181  ...
# ...

# %%
RHD143_df.to_csv('/Users/soumyadeepray/Documents/Research_Project-Nutrition_Sciences/NHANES/data/RHD143.csv')

# %%
RHQ076_df = df[(df['RHQ076']== 1.0)]

# %%
RHQ076_df.describe()
# Out:
#                 SEQN       WTDRD1PP      WTDR2DPP     DR1ILINE  DR1DRSTZ  \
# count    3124.000000    3124.000000  3.124000e+03  3124.000000    3124.0
# mean   116881.896607   37400.870327  4.359945e+04     9.670615       1.0
# std      4427.073909   44181.473528  5.915731e+04     6.294971       0.0
# min    109291.000000    1727.251573  5.397605e-79     1.000000       1.0
# 25%    113109.000000   12504.240914  1.096138e+04     5.000000       1.0
# 50%    116706.000000   20981.742096  2.183537e+04     9.000000       1.0
# 75%    120519.000000   43246.720318  4.649075e+04    14.000000       1.0
# max    124813.000000  253485.315766  3.309517e+05    32.000000       1.0
#
#           DR1EXMER   DRABF       DRDINT      DR1DBIH       DR1DAY  ...  \
# count  3124.000000  3124.0  3124.000000  2964.000000  3124.000000  ...
# mean     72.341229     2.0     1.915493    11.213225     5.013124  ...
# std      21.579395     0.0     0.278191    13.582329     2.090834  ...
# ...

# %%
RHQ076_df
# Out:
#            SEQN      WTDRD1PP      WTDR2DPP  DR1ILINE  DR1DRSTZ  DR1EXMER  \
# 110    109291.0  12733.439510  27963.088586       4.0       1.0      49.0
# 111    109291.0  12733.439510  27963.088586      14.0       1.0      49.0
# 112    109291.0  12733.439510  27963.088586      15.0       1.0      49.0
# 113    109291.0  12733.439510  27963.088586       3.0       1.0      49.0
# 114    109291.0  12733.439510  27963.088586       9.0       1.0      49.0
# ...         ...           ...           ...       ...       ...       ...
# 71935  124813.0   7457.881926   5816.929324       5.0       1.0      90.0
# 71936  124813.0   7457.881926   5816.929324       4.0       1.0      90.0
# 71937  124813.0   7457.881926   5816.929324       3.0       1.0      90.0
# 71938  124813.0   7457.881926   5816.929324       2.0       1.0      90.0
# 71939  124813.0   7457.881926   5816.929324       1.0       1.0      90.0
#
#        DRABF  DRDINT  DR1DBIH  DR1DAY  ...  RHD280  RHQ305  RHQ332  RHQ540  \
# ...

# %%
RHD143_df
# Out:
#            SEQN      WTDRD1PP      WTDR2DPP  DR1ILINE  DR1DRSTZ  DR1EXMER  \
# 889    109447.0  33026.862559  28231.480109       9.0       1.0      88.0
# 890    109447.0  33026.862559  28231.480109       1.0       1.0      88.0
# 891    109447.0  33026.862559  28231.480109       2.0       1.0      88.0
# 892    109447.0  33026.862559  28231.480109       6.0       1.0      88.0
# 893    109447.0  33026.862559  28231.480109      16.0       1.0      88.0
# ...         ...           ...           ...       ...       ...       ...
# 71722  124780.0  19937.540621  17042.680953       5.0       1.0      14.0
# 71723  124780.0  19937.540621  17042.680953       4.0       1.0      14.0
# 71724  124780.0  19937.540621  17042.680953       3.0       1.0      14.0
# 71725  124780.0  19937.540621  17042.680953       2.0       1.0      14.0
# 71726  124780.0  19937.540621  17042.680953       1.0       1.0      14.0
#
#        DRABF  DRDINT  DR1DBIH  DR1DAY  ...  RHD280  RHQ305  RHQ332  RHQ540  \
# ...

# %%
RHQ076_df.to_csv('/Users/soumyadeepray/Documents/Research_Project-Nutrition_Sciences/NHANES/data/RHQ076.csv')

# %%
n = len(pd.unique(RHD143_df['SEQN']))
print("No.of.unique values :", n)
# Out:
# No.of.unique values : 64

# %%
n = len(pd.unique(RHQ076_df['SEQN']))
print("No.of.unique values :", n)
# Out:
# No.of.unique values : 195

# %%
RHD143_df_transposed = RHD143_df.T
RHD143_df_transposed
# Out:
#                   889            890            891            892    \
# SEQN      109447.000000  109447.000000  109447.000000  109447.000000
# WTDRD1PP   33026.862559   33026.862559   33026.862559   33026.862559
# WTDR2DPP   28231.480109   28231.480109   28231.480109   28231.480109
# DR1ILINE       9.000000       1.000000       2.000000       6.000000
# DR1DRSTZ       1.000000       1.000000       1.000000       1.000000
# ...                 ...            ...            ...            ...
# RHQ542B             NaN            NaN            NaN            NaN
# RHQ542C             NaN            NaN            NaN            NaN
# RHQ542D             NaN            NaN            NaN            NaN
# RHQ554              NaN            NaN            NaN            NaN
# RHQ570              NaN            NaN            NaN            NaN
#
#                   893            894            895            896    \
# ...
